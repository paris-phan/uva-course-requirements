# %%
# %reset -f
import pandas as pd

# %%
mathPrerequisiteRequirement = []
mathCoreRequirement = []
mathElectiveRequirement = []

csPrerequisiteRequirement = []
csCoreRequirement = []
csElectiveRequirement = []

collegeEngagementRequirement = []
collegeLiteracyRequirement = []
collegeDisciplineRequirement = []

# %%
#math prereqs
mathPrerequisiteCourses = {"required": 1,
                           "MATH 2310": False,
                           "MATH 2315": False,
                           "APMA 2120": False
                           }

mathPrerequisiteRequirement.append(mathPrerequisiteCourses)

#math cores
mathCoreDifferentialEquationsCourses = {"required": 1,
                                        "MATH 3250": False,
                                        "MATH 4250": False,
                                        "MATH 3315": False
                                        }

mathCoreLinearAlgebraCourses = {"required": 1,
                                "MATH 3351": False,
                                "MATH 4651": False,
                                "MATH 3315": False
                                }

mathCoreRealAnalysisCourses = {"required": 1,
                                "MATH 3310": False,
                                "MATH 4310": False
                                }

mathCoreAbstractAlgebraCourses = {"required": 1,
                                "MATH 3354": False,
                                "MATH 4652": False
                                }

mathCoreFinancialCourses = {"required": 3,
                            "MATH 3100": False,
                            "MATH 4140": False,
                            "STAT 3120": False
                            }

mathCoreRequirement.append(mathCoreDifferentialEquationsCourses)
mathCoreRequirement.append(mathCoreLinearAlgebraCourses)
mathCoreRequirement.append(mathCoreRealAnalysisCourses)
mathCoreRequirement.append(mathCoreAbstractAlgebraCourses)
mathCoreRequirement.append(mathCoreFinancialCourses)

# %%
#cs prereqs
csPrerequisiteIntroCourses = {"required": 1,
                            "CS 1110": False,
                            "CS 1111": False,
                            "CS 1112": False,
                            "CS 1113": False,
                            "CS 1120": False
                         }
csPrerequisiteCourses = {"required": 1,
                         "CS 2100": False
                         }

csPrerequisiteRequirement.append(csPrerequisiteIntroCourses)
csPrerequisiteRequirement.append(csPrerequisiteCourses)


#cs cores
csCoreCourses = {"required": 6,
                 "CS 2120": False,
                 "CS 2130": False,
                 "CS 3100": False,
                 "CS 3120": False,
                 "CS 3130": False,
                 "CS 3140": False,
                 }

csCoreRequirement.append(csCoreCourses)

# %%
mathElectiveGeneralCourses = {"required": 2,
                              "CS 3100": False,
                              "CS 3102": False,
                              "ECON 4010": False,
                              "PHIL 5420": False,
                              "PHIL 5470": False,
                              "STAT 3120": False,
                              "STAT 5265": False,
                              "SYS 3021": False,
                              "SYS 3060": False,
                              "MATH 3000": False,
                              "MATH 3315": False,
                              "MATH 3340": False,
                              "MATH 3350": False,
                              "MATH 4110": False,
                              "MATH 4250": False,
                              "MATH 4300": False,
                              "MATH 4330": False,
                              "MATH 4559": False,
                              "MATH 4651": False,
                              "MATH 4652": False,
                              "MATH 4840": False,
                              "MATH 4993": False
                              }

mathElectiveFinanceCourses = {"required": 2,
                              "COMM 2010": False,
                              "COMM 2020": False,
                              "ECON 2010": False,
                              "COMM 2020": False
                              }

matElectiveComputingCourses = {"required": 1,
                               "CS 1110": False,
                               "CS 1111": False,
                               "CS 1112": False,
                               "CS 1113": False,
                               "CS 1120": False,
                               "PHYS 2660": False
                               }

mathElectiveRequirement.append(mathElectiveGeneralCourses)
mathElectiveRequirement.append(mathElectiveFinanceCourses)
mathElectiveRequirement.append(matElectiveComputingCourses)

# %%
csElectiveRestrictedCourses = {"required": 3,
                               "CS 3205": False,
                               "CS 3240": False,
                               "CS 3250": False,
                               "CS 3501": False,
                               "CS 3710": False,
                               "CS 4240": False,
                               "CS 4260": False,
                               "CS 4330": False,
                               "CS 4414": False,
                               "CS 4434": False,
                               "CS 4444": False,
                               "CS 4457": False,
                               "CS 4458": False,
                               "CS 4501": False,
                               "CS 4610": False,
                               "CS 4620": False,
                               "CS 4630": False,
                               "CS 4640": False,
                               "CS 4710": False,
                               "CS 4720": False,
                               "CS 4730": False,
                               "CS 4740": False,
                               "CS 4750": False,
                               "CS 4753": False,
                               "CS 4760": False,
                               "CS 4774": False,
                               "CS 4780": False,
                               "CS 4810": False,
                               "CS 4993": False
                               }

csElectiveIntegratedCourses = {"required": 4,
                               "AMST 3463": False,
                               "ANTH 3490": False,
                               "ARTS 2220": False,
                               "ARTS 2222": False,
                               "ARTS 3220": False,
                               "ARTS 3222": False,
                               "ARTS 4220": False,
                               "ARTS 4222": False,
                               "BIOL 4230": False,
                               "DRAM 2110": False,
                               "DRAM 2210": False,
                               "DRAM 2620": False,
                               "DRAM 3820": False,
                               "DRAM 3825": False,
                               "DRAM 4110": False,
                               "ECON 3720": False,
                               "ECON 4010": False,
                               "ECON 4020": False,
                               "ECON 4030": False,
                               "ECON 4444": False,
                               "ECON 4720": False,
                               "ECON 4730": False,
                               "EVSC 3020": False,
                               "EVSC 4010": False,
                               "EVSC 4015": False,
                               "EVSC 4070": False,
                               "EVSC 4080": False,
                               "HIST 2212": False,
                               "HIUS 3162": False,
                               "LING 3400": False,
                               "LNGS 3250": False,
                               "MATH 3100": False,
                               "MATH 3315": False,
                               "MATH 3350": False,
                               "MATH 3351": False,
                               "MATH 3354": False,
                               "MATH 4300": False,
                               "MATH 4651": False,
                               "MDST 2000": False,
                               "MDST 3050": False,
                               "MDST 3108": False,
                               "MDST 3120": False,
                               "MDST 3320": False,
                               "MDST 3404": False,
                               "MDST 3405": False,
                               "MDST 3430": False,
                               "MDST 3504": False,
                               "MDST 3665": False,
                               "MDST 3701": False,
                               "MDST 3703": False,
                               "MDST 3712": False,
                               "MDST 3750": False,
                               "MDST 3751": False,
                               "MDST 3755": False,
                               "MDST 4101": False,
                               "MDST 4803": False,
                               "MUSI 2350": False,
                               "MUSI 2390": False,
                               "MUSI 3374": False,
                               "MUSI 3390": False,
                               "MUSI 4535": False,
                               "MUSI 4540": False,
                               "MUSI 4543": False,
                               "MUSI 4545": False,
                               "MUSI 4600": False,
                               "MUSI 4610": False,
                               "MUSI 4620": False,
                               "PHIL 1410": False,
                               "PHIL 1510": False,
                               "PHIL 2330": False,
                               "PHIL 2340": False,
                               "PHIL 2420": False,
                               "PHIL 3400": False,
                               "PHIL 3620": False,
                               "PHYS 2660": False,
                               "PSYC 2100": False,
                               "PSYC 2150": False,
                               "PSYC 2200": False,
                               "PSYC 2300": False,
                               "PSYC 2700": False,
                               "PSYC 3160": False,
                               "PSYC 3310": False,
                               "PSYC 4110": False,
                               "PSYC 4200": False,
                               "PSYC 4681": False,
                               "PSYC 4682": False,
                               "RELG 3001": False,
                               "SOC 4780": False,
                               "STAT 1100": False,
                               "STAT 1120": False,
                               "STAT 2020": False,
                               "STAT 2120": False,
                               "STAT 3080": False,
                               "STAT 3110": False,
                               "STAT 3120": False,
                               "STAT 3220": False,
                               "STAT 3280": False,
                               "STAT 4220": False,
                               "STAT 4630": False
                               }

csElectiveRequirement.append(csElectiveRestrictedCourses)
csElectiveRequirement.append(csElectiveIntegratedCourses)

# %%
file_path = 'discipline_artistic.csv'
df = pd.read_csv(file_path)

course_column =

# %%
mathDegree = { "completed": False,
               "prerequisites" : mathPrerequisiteRequirement,
               "core" : mathCoreRequirement,
               "elective" : mathElectiveRequirement
               }
csDegree = { "completed": False,
             "prerequisites" : csPrerequisiteRequirement,
             "core" : csCoreRequirement,
             "elective" : csElectiveRequirement
             }

collegeDegree = { "completed": False,
                  "engagement" : collegeEngagementRequirement,
                  "literacy" : collegeLiteracyRequirement,
                  "discipline" : collegeDisciplineRequirement
                  }
